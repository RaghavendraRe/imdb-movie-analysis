# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
df = pd.read_csv("lst700movies.csv")

# %%
df.head()
# Out:
#                        Title  Year  Rating           Directors  \
# 0                       Jaat  2025     6.9  Gopichand Malineni
# 1                    Chhaava  2025     7.4       Laxman Utekar
# 2              Good Bad Ugly  2025     7.1  Adhik Ravichandran
# 3  Court - State vs a Nobody  2025     8.0       Ram Jagadeesh
# 4                       Deva  2025     6.8    Rosshan Andrrews
#
#                                                Stars Votes Languages Duration  \
# 0         Sunny Deol,Randeep Hooda,Regena Cassandrra  5.3K     Hindi   2h 38m
# 1     Vicky Kaushal,Akshaye Khanna,Rashmika Mandanna   30K     Hindi   2h 41m
# 2  Ajith Kumar,Trisha Krishnan,Priya Prakash Varrier  7.9K     Tamil   2h 19m
# 3        Priyadarshi Pulikonda,Harsh Roshan,Sri Devi  4.9K    Telugu   2h 35m
# 4            Pooja Hegde,Shahid Kapoor,Saadhika Syal   24K     Hindi   2h 36m
#
#   Gross Worldwide                         Production Company  \
# ...

# %%
dc = df.copy()

# %%
dc.head()
# Out:
#                        Title  Year  Rating           Directors  \
# 0                       Jaat  2025     6.9  Gopichand Malineni
# 1                    Chhaava  2025     7.4       Laxman Utekar
# 2              Good Bad Ugly  2025     7.1  Adhik Ravichandran
# 3  Court - State vs a Nobody  2025     8.0       Ram Jagadeesh
# 4                       Deva  2025     6.8    Rosshan Andrrews
#
#                                                Stars Votes Languages Duration  \
# 0         Sunny Deol,Randeep Hooda,Regena Cassandrra  5.3K     Hindi   2h 38m
# 1     Vicky Kaushal,Akshaye Khanna,Rashmika Mandanna   30K     Hindi   2h 41m
# 2  Ajith Kumar,Trisha Krishnan,Priya Prakash Varrier  7.9K     Tamil   2h 19m
# 3        Priyadarshi Pulikonda,Harsh Roshan,Sri Devi  4.9K    Telugu   2h 35m
# 4            Pooja Hegde,Shahid Kapoor,Saadhika Syal   24K     Hindi   2h 36m
#
#   Gross Worldwide                         Production Company  \
# ...

# %%
dc.shape
# Out:
# (700, 11)

# %%
dc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               700 non-null    object
#  1   Year                700 non-null    int64
#  2   Rating              658 non-null    float64
#  3   Directors           646 non-null    object
#  4   Stars               601 non-null    object
#  5   Votes               658 non-null    object
#  6   Languages           700 non-null    object
#  7   Duration            688 non-null    object
#  8   Gross Worldwide     456 non-null    object
#  9   Production Company  691 non-null    object
#  10  Genres              692 non-null    object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 60.3+ KB

# %%
dc.describe()
# Out:
#               Year      Rating
# count   700.000000  658.000000
# mean   2019.158571    7.013374
# std       6.913671    1.236090
# min    1987.000000    1.200000
# 25%    2017.000000    6.400000
# 50%    2022.000000    7.200000
# 75%    2024.000000    8.000000
# max    2025.000000    9.800000

# %%
dc.isnull().sum() #isna and isnull both are same
# Out:
# Title                   0
# Year                    0
# Rating                 42
# Directors              54
# Stars                  99
# Votes                  42
# Languages               0
# Duration               12
# Gross Worldwide       244
# Production Company      9
# Genres                  8
# dtype: int64

# %%
dc.isnull().sum(axis=0).sort_values(ascending = False)
# Out:
# Gross Worldwide       244
# Stars                  99
# Directors              54
# Rating                 42
# Votes                  42
# Duration               12
# Production Company      9
# Genres                  8
# Title                   0
# Year                    0
# Languages               0
# dtype: int64

# %%
dc.dtypes
# Out:
# Title                  object
# Year                    int64
# Rating                float64
# Directors              object
# Stars                  object
# Votes                  object
# Languages              object
# Duration               object
# Gross Worldwide        object
# Production Company     object
# Genres                 object
# dtype: object

# %%
dc['Title'].duplicated().sum()  # Checking duplicate Titles
# Out:
# 6

# %%
dc[dc['Title'].duplicated(keep=False)]    # Checking duplicate Titles

# Observations about duplicated titles:
# - Some movie titles are the same (like Drishyam, Ghajini, Kick, Vikram Vedha, U Turn).
# - After checking carefully:
#    - They are different because of language (Hindi, Tamil, Telugu, Malayalam).
#    - Or they are sequels (Part 1, Part 2).
# - Therefore, no removal is needed. We will keep all titles.
# Out:
#             Title  Year  Rating                       Directors  \
# 95       Drishyam  2015     8.2                 Nishikant Kamat
# 178    Drishyam 2  2022     8.2                 Abhishek Pathak
# 180       Ghajini  2008     7.4                 A.R. Murugadoss
# 223          Kick  2014     6.0                Sajid Nadiadwala
# 227  Vikram Vedha  2022     7.1                  GayatriPushkar
# 266  Vikram Vedha  2017     8.2  GayatriPushkarGowtham Selvaraj
# 272       Ghajini  2005     7.6                 A.R. Murugadoss
# 370        U Turn  2016     7.4                     Pawan Kumar
# 437      Drishyam  2013     8.4                   Jeethu Joseph
# 438    Drishyam 2  2021     8.4                   Jeethu Joseph
# 584          Kick  2009     NaN                             NaN
# 585        U Turn  2018     6.9                     Pawan Kumar
#
#                                                  Stars Votes  \
# 95                             Ajay Devgn,Shriya Saran  101K
# ...

# %%
dc['Year'].isnull().sum()
# Out:
# 0

# %%
print(dc['Year'].min())
print(dc['Year'].max())
# Out:
# 1987
# 2025

# %%
dc['Rating'].isnull().sum()
# Out:
# 42

# %%
print(dc['Rating'].min())
print(dc['Rating'].max())
# Out:
# 1.2
# 9.8

# %%
dc['Rating'].describe()
# Out:
# count    658.000000
# mean       7.013374
# std        1.236090
# min        1.200000
# 25%        6.400000
# 50%        7.200000
# 75%        8.000000
# max        9.800000
# Name: Rating, dtype: float64

# %%
rating_median = dc['Rating'].median()
dc['Rating'] = dc['Rating'].fillna(rating_median)

# %%
print("Missing Ratings after filling:", dc['Rating'].isnull().sum())
# Out:
# Missing Ratings after filling: 0

# %%
# Observation for Rating column:
# - 42 missing ratings were found.
# - Ratings are between 1.2 and 9.8, which is logical.
#filling with median  # 42 missing Ratings were filled using Median in df4

# %%
# Check data type
print(dc['Votes'].dtypes)
# Out:
# object

# %%
# Check few sample values
print(dc['Votes'].head(10))
# Out:
# 0    5.3K
# 1     30K
# 2    7.9K
# 3    4.9K
# 4     24K
# 5    4.3K
# 6     11K
# 7     56K
# 8     49K
# 9     32K
# Name: Votes, dtype: object

# %%
# Check missing values
print("Missing Votes before filling:", dc['Votes'].isnull().sum())
# Out:
# Missing Votes before filling: 42

# %%
print(dc['Votes'].tail(10))
# Out:
# 690    7.7K
# 691    4.8K
# 692    2.3K
# 693     11K
# 694     41K
# 695     59K
# 696     354
# 697     48K
# 698    4.4K
# 699     25K
# Name: Votes, dtype: object

# %%
def convert_votes(vote_str):
    try:
        vote_str = str(vote_str).strip("()")  
        if 'M' in vote_str:
            return int(float(vote_str.replace('M', '')) * 1000000)
        elif 'K' in vote_str:
            return int(float(vote_str.replace('K', '')) * 1000)
        else:
            return int(vote_str)
    except:
        return np.nan


dc['Votes'] = dc['Votes'].apply(convert_votes)

# %%
#  Fill missing Votes with median
votes_median = dc['Votes'].median()
dc['Votes'] = dc['Votes'].fillna(votes_median)

# %%
#  Confirm missing
print(dc['Votes'].isnull().sum())
# Out:
# 0

# %%
dc['Votes'].tail(10)
# Out:
# 690     7700.0
# 691     4800.0
# 692     2300.0
# 693    11000.0
# 694    41000.0
# 695    59000.0
# 696      354.0
# 697    48000.0
# 698     4400.0
# 699    25000.0
# Name: Votes, dtype: float64

# %% [raw]
# Votes Cleaning Observation:
#
# Successfully cleaned 'K' values by converting them to full numbers.
#
# Preserved small vote counts like 354 correctly without wrong multiplication.
#
# All Votes are now numeric (float64) type.
#
# No missing values remain after cleaning.

# %%
print(dc['Duration'].head(10))
# Out:
# 0    2h 38m
# 1    2h 41m
# 2    2h 19m
# 3    2h 35m
# 4    2h 36m
# 5    2h 13m
# 6    2h 37m
# 7    3h 21m
# 8    2h 28m
# 9    2h 28m
# Name: Duration, dtype: object

# %%
# Check missing values
print(dc['Duration'].isnull().sum())
# Out:
# 12

# %%
#Extract hours and minutes separately
dc["hours"] = dc["Duration"].str.extract(r'(\d+)h').astype(float)
dc["minutes"] = dc["Duration"].str.extract(r'(\d+)m').astype(float)

# Fill missing values with 0
dc['hours'] = dc['hours'].fillna(0)
dc['minutes'] = dc['minutes'].fillna(0)

#  Calculate total minutes
dc['total_minute'] = dc['hours'] * 60 + dc['minutes']

#  Convert total_minute to integer
dc['total_minute'] = dc['total_minute'].astype(int)

# Drop the helper columns
dc.drop(columns=['hours', 'minutes'], axis=1, inplace=True)

#  Drop the original Duration column
dc.drop(columns=["Duration"], axis=1, inplace=True)

# %%
#  Check final result
print(dc[['total_minute']].head(10))
# Out:
#    total_minute
# 0           158
# 1           161
# 2           139
# 3           155
# 4           156
# 5           133
# 6           157
# 7           201
# 8           148
# 9           148

# %%
print(dc['total_minute'].dtype)
# Out:
# int32

# %%
print(dc['total_minute'].isnull().sum())
# Out:
# 0

# %%
print(dc['total_minute'].head(10))
# Out:
# 0    158
# 1    161
# 2    139
# 3    155
# 4    156
# 5    133
# 6    157
# 7    201
# 8    148
# 9    148
# Name: total_minute, dtype: int32

# %%
#  Find the mode of total_minute
mode_duration = dc['total_minute'].mode()[0]
print("Mode value for total_minute:", mode_duration)

#  Replace 0 minutes with mode value
dc['total_minute'] = dc['total_minute'].replace(0, mode_duration)

# Confirm that 0 minutes are gone
print("Number of 0 minute movies after filling:", (dc['total_minute'] == 0).sum())
# Out:
# Mode value for total_minute: 150
# Number of 0 minute movies after filling: 0

# %%
#See first few rows
print(dc[['Title', 'total_minute']].head(20))
# Out:
#                         Title  total_minute
# 0                        Jaat           158
# 1                     Chhaava           161
# 2               Good Bad Ugly           139
# 3   Court - State vs a Nobody           155
# 4                        Deva           156
# 5            Kesari Chapter 2           133
# 6                      Dragon           157
# 7             Pushpa the Rule           201
# 8                    Sikandar           148
# 9               Lucky Baskhar           148
# 10               The Diplomat           130
# 11                  Chhorii 2           132
# 12                    Chhorii           129
# 13                  12th Fail           147
# 14                     Crazxy            93
# 15                     Perusu           125
# 16  14 Days: Girlfriend Intlo            90
# 17                   3 Idiots           170
# 18              Rekhachithram           147
# 19         Alappuzha Gymkhana           139

# %% [raw]
# he Mode (most frequent value) is a good way to fill missing values when:
#
# The missing values are few .
#
# The Mode makes sense for the column (Duration is okay for this).

# %%
print(dc['Genres'].head(10))
# Out:
# 0    Action Epic, One-Person Army Action, Action, D...
# 1    Action Epic, Costume Drama, Epic, Historical E...
# 2                              Action, Drama, Thriller
# 3                                   Legal Drama, Drama
# 4    Cop Drama, One-Person Army Action, Police Proc...
# 5    Docudrama, Legal Drama, Period Drama, Biograph...
# 6    Coming-of-Age, Psychological Drama, Comedy, Dr...
# 7    Action Epic, One-Person Army Action, Action, C...
# 8    Action Epic, One-Person Army Action, Tragedy, ...
# 9                        Caper, Crime, Drama, Thriller
# Name: Genres, dtype: object

# %%
print(dc['Genres'].unique())
# Out:
# ['Action Epic, One-Person Army Action, Action, Drama, Thriller'
#  'Action Epic, Costume Drama, Epic, Historical Epic, One-Person Army Action, Period Drama, Tragedy, Action, Drama, History'
#  'Action, Drama, Thriller' 'Legal Drama, Drama'
#  'Cop Drama, One-Person Army Action, Police Procedural, Psychological Thriller, Suspense Mystery, Whodunnit, Action, Crime, Drama, Mystery'
#  'Docudrama, Legal Drama, Period Drama, Biography, Drama, History'
#  'Coming-of-Age, Psychological Drama, Comedy, Drama, Romance'
#  'Action Epic, One-Person Army Action, Action, Crime, Drama, Thriller'
#  'Action Epic, One-Person Army Action, Tragedy, Action, Drama, Thriller'
#  'Caper, Crime, Drama, Thriller'
#  'Legal Drama, Political Drama, Political Thriller, Drama, Thriller'
#  'Horror' 'Folk Horror, Supernatural Horror, Drama, Horror, Thriller'
#  'Docudrama, Biography, Drama' 'Conspiracy Thriller, Thriller' 'Comedy'
#  'Quirky Comedy, Comedy'
# ...

# %%
print("Total unique genre combinations = ", dc['Genres'].nunique())
# Out:
# Total unique genre combinations =  361

# %%
print("Missing values in Genres = ", dc['Genres'].isnull().sum())
# Out:
# Missing values in Genres =  8

# %%
#  Fill missing Genres with 'Unknown'
dc['Genres'] = dc['Genres'].fillna('Unknown')

#  Create a function to get last 3 genres
def get_last_genres(genre_str):
    genres_list = genre_str.split(',')
    genres_list = [g.strip() for g in genres_list]  # remove spaces
    if len(genres_list) >= 3:
        return ', '.join(genres_list[-3:])  # take LAST 3
    else:
        return ', '.join(genres_list)  # take all available

#  Apply the function
dc['Main_Genre'] = dc['Genres'].apply(get_last_genres)

# %%
#  Check
pd.set_option('display.max_rows', 1000)  # You can set 1000 or more if needed

# Now print
dc[['Title', 'Main_Genre']]
# Out:
#                                                  Title  \
# 0                                                 Jaat
# 1                                              Chhaava
# 2                                        Good Bad Ugly
# 3                            Court - State vs a Nobody
# 4                                                 Deva
# 5                                     Kesari Chapter 2
# 6                                               Dragon
# 7                                      Pushpa the Rule
# 8                                             Sikandar
# 9                                        Lucky Baskhar
# 10                                        The Diplomat
# 11                                           Chhorii 2
# 12                                             Chhorii
# 13                                           12th Fail
# 14                                              Crazxy
# 15                                              Perusu
# ...

# %%
genre_mapping = {
    'Action Epic': 'Action',
    'One-Person Army Action': 'Action',
    'Cop Drama': 'Crime',
    'Legal Drama': 'Drama',
    'Psychological Drama': 'Drama',
    'Political Drama': 'Drama',
    'Docudrama': 'Drama',
    'Coming-of-Age': 'Drama',
    'Martial Arts': 'Action',
    'Romantic Comedy': 'Comedy',
    'Quirky Comedy': 'Comedy',
    'Buddy Comedy': 'Comedy',
    'Dark Comedy': 'Comedy',
    'Slapstick': 'Comedy',
    'Showbiz Drama': 'Drama',
    'Folk Horror': 'Horror',
    'Supernatural Horror': 'Horror',
    'Psychological Thriller': 'Thriller',
    'Conspiracy Thriller': 'Thriller',
    'Political Thriller': 'Thriller',
    'Suspense Mystery': 'Mystery',
    'Quest': 'Adventure',
    'Adventure Epic': 'Adventure',
    'Historical Epic': 'History',
    'War Epic': 'War',
    'Medical Drama': 'Drama',
    'Crime Documentary': 'Crime',
    'Spy': 'Action',
    'Road Trip': 'Adventure',
    'Jungle Adventure': 'Adventure',
    'Artificial Intelligence': 'Sci-Fi',
    'Body Horror': 'Horror',
    'Serial Killer': 'Crime',
    'True Crime': 'Crime',
    'Parody': 'Comedy',
    'Heist': 'Crime',
    'Monster Horror': 'Horror',
    'Swashbuckler': 'Adventure'
}

# %%
def clean_main_genre(genre_list):
    if pd.isnull(genre_list):
        return 'Unknown'
    parts = genre_list.split(',')
    cleaned = []
    for part in parts:
        part = part.strip()
        if part in genre_mapping:
            cleaned.append(genre_mapping[part])
        else:
            cleaned.append(part)
    return ', '.join(cleaned)

    
dc['Genre_Cleaned'] = dc['Main_Genre'].apply(clean_main_genre)

# %%
print(dc['Genre_Cleaned'].head(20))
# Out:
# 0       Action, Drama, Thriller
# 1        Action, Drama, History
# 2       Action, Drama, Thriller
# 3                  Drama, Drama
# 4         Crime, Drama, Mystery
# 5     Biography, Drama, History
# 6        Comedy, Drama, Romance
# 7        Crime, Drama, Thriller
# 8       Action, Drama, Thriller
# 9        Crime, Drama, Thriller
# 10    Thriller, Drama, Thriller
# 11                       Horror
# 12      Drama, Horror, Thriller
# 13      Drama, Biography, Drama
# 14           Thriller, Thriller
# 15                       Comedy
# 16               Comedy, Comedy
# 17        Comedy, Comedy, Drama
# 18     Drama, Mystery, Thriller
# 19        Action, Comedy, Drama
# Name: Genre_Cleaned, dtype: object

# %%
def remove_duplicates(genre_string):
    if pd.isnull(genre_string):
        return 'Unknown'
    parts = genre_string.split(',')
    parts = [part.strip() for part in parts]
    parts = list(dict.fromkeys(parts))  # Remove duplicates and keep order
    return ', '.join(parts)

# Apply to Genre_Cleaned
dc['Genre_Cleaned'] = dc['Genre_Cleaned'].apply(remove_duplicates)

# %%
print(dc['Genre_Cleaned'].head(20))
# Out:
# 0       Action, Drama, Thriller
# 1        Action, Drama, History
# 2       Action, Drama, Thriller
# 3                         Drama
# 4         Crime, Drama, Mystery
# 5     Biography, Drama, History
# 6        Comedy, Drama, Romance
# 7        Crime, Drama, Thriller
# 8       Action, Drama, Thriller
# 9        Crime, Drama, Thriller
# 10              Thriller, Drama
# 11                       Horror
# 12      Drama, Horror, Thriller
# 13             Drama, Biography
# 14                     Thriller
# 15                       Comedy
# 16                       Comedy
# 17                Comedy, Drama
# 18     Drama, Mystery, Thriller
# 19        Action, Comedy, Drama
# Name: Genre_Cleaned, dtype: object

# %%
print(dc['Genre_Cleaned'].isnull().sum())
# Out:
# 0

# %%
dc
# Out:
#                                                  Title  Year  Rating  \
# 0                                                 Jaat  2025     6.9
# 1                                              Chhaava  2025     7.4
# 2                                        Good Bad Ugly  2025     7.1
# 3                            Court - State vs a Nobody  2025     8.0
# 4                                                 Deva  2025     6.8
# 5                                     Kesari Chapter 2  2025     8.5
# 6                                               Dragon  2025     7.9
# 7                                      Pushpa the Rule  2024     6.1
# 8                                             Sikandar  2025     4.3
# 9                                        Lucky Baskhar  2024     8.0
# 10                                        The Diplomat  2025     7.5
# 11                                           Chhorii 2  2025     4.6
# 12                                             Chhorii  2021     6.7
# ...

# %%
# Check data type
print(dc['Gross Worldwide'].dtypes)
# Out:
# object

# %%
# See sample values
print(dc['Gross Worldwide'].head(10))
# Out:
# 0        508,023
# 1      8,219,603
# 2      1,452,831
# 3        133,791
# 4      1,091,296
# 5        645,281
# 6        738,241
# 7    154,621,981
# 8      3,018,841
# 9        987,421
# Name: Gross Worldwide, dtype: object

# %%
# Check missing values
print(dc['Gross Worldwide'].isnull().sum())
# Out:
# 244

# %%
#Code to Clean Gross Worldwide

# %%
dc['Gross Worldwide'] = dc['Gross Worldwide'].str.replace(',', '', regex=False)

# %%
# Convert to numeric
dc['Gross Worldwide'] = pd.to_numeric(dc['Gross Worldwide'], errors='coerce')

# %%
#Check again
print(dc['Gross Worldwide'].dtypes)
# Out:
# float64

# %%
print(dc['Gross Worldwide'].head(10))
# Out:
# 0       508023.0
# 1      8219603.0
# 2      1452831.0
# 3       133791.0
# 4      1091296.0
# 5       645281.0
# 6       738241.0
# 7    154621981.0
# 8      3018841.0
# 9       987421.0
# Name: Gross Worldwide, dtype: float64

# %%
print(dc['Gross Worldwide'].isnull().sum())
# Out:
# 244

# %%
#  Fill missing Gross Worldwide using Genre_Cleaned group median
dc['Gross Worldwide'] = dc['Gross Worldwide'].fillna(
    dc.groupby('Genre_Cleaned')['Gross Worldwide'].transform('median')
)

#  If still missing, fill using overall median
dc['Gross Worldwide'] = dc['Gross Worldwide'].fillna(
    dc['Gross Worldwide'].median()
)

# %%
print(dc['Gross Worldwide'].isnull().sum())
# Out:
# 0

# %% [raw]
# Because:
#
# Many movies (especially new movies, small movies, regional movies) don't report official earnings.
#
# It is normal for IMDb scraping projects.
#
# Gross Worldwide is often missing for smaller or recent movies

# %%
# Observation for Gross Worldwide column:
# - Initially, Gross Worldwide had commas and text format.
# - After cleaning, it is converted into numeric type (float64).
# - 206 movies have missing Gross data (common for small/new movies).
# - ### not doing this - We kept missing values as NaN for realistic analysis.

# %%
#Why?

#Step	Why it is good
#Fill by Genre Median	- Different Genres earn differently (Action movies usually earn more than Art movies) — so Genre-wise median is more logical
#Fill remaining with Overall Median	- If Genre data is not available, then overall median gives a safe fallback

# %% [markdown]
# ## Column: [Directors],  [stars] and [production_company]

# %%
print(dc['Directors'].isnull().sum())
print(dc['Stars'].isnull().sum())
print(dc['Production Company'].isnull().sum())

# %%
# Fill missing values in Directors
dc['Directors'] = dc['Directors'].fillna('Unknown')

# %%
# Fill missing values in Stars
dc['Stars'] = dc['Stars'].fillna('Unknown')

# %%
# Fill missing values in Production Company
dc['Production Company'] = dc['Production Company'].fillna('Unknown')

# %%
dc[['Directors']].sample(10)

# %%
print(dc['Directors'].isnull().sum())
print(dc['Stars'].isnull().sum())
print(dc['Production Company'].isnull().sum())

# %%
dc['Genres'].value_counts()[0:10] #top 10 most frequent genres

# %%
dc.isnull().sum(axis=1).sort_values(ascending = False)

# %%
dc.isnull().sum(axis=0).sort_values(ascending = False)/len(dc)*100

# %%
print(dc['Languages'].isnull().sum())

# %%
dc['Languages'].head(20)

# %%
# Create new Primary_Language column
dc['Primary_Language'] = dc['Languages'].apply(lambda x: x.split(',')[0].strip())

# %%
print(dc.isnull().sum())

# %%
print(dc.dtypes)

# %%
dc['Votes'] = dc['Votes'].astype('Int64')

# %%
dc['Votes']

# %%
#dff.to_csv('latestimdb_700_movies_cleaned_final.csv', index=False)
